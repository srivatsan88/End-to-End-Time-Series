# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/End-to-End-Time-Series/blob/master/Multiple_Time_Series_using_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link to video explaining the code - https://www.youtube.com/watch?v=UhxCsweuKE4

# %%
# !pip install download

# %%
# !pip install fbprophet

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
import pandas as pd
import plotly.express as px

from download import download


mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['axes.grid'] = False

# %%
path = download('https://archive.ics.uci.edu/ml/machine-learning-databases/00501/PRSA2017_Data_20130301-20170228.zip', '/tmp/aq', kind="zip")
# Out:
# Creating data folder...
# Downloading data from https://archive.ics.uci.edu/ml/machine-learning-databases/00501/PRSA2017_Data_20130301-20170228.zip (7.6 MB)
#
# file_sizes: 100%|██████████████████████████| 7.96M/7.96M [00:00<00:00, 12.6MB/s]
# Extracting zip file...
# Successfully downloaded / unzipped to /tmp/aq

# %%
# !ls /tmp/aq/PRSA_Data_20130301-20170228
# Out:
# PRSA_Data_Aotizhongxin_20130301-20170228.csv
# PRSA_Data_Changping_20130301-20170228.csv
# PRSA_Data_Dingling_20130301-20170228.csv
# PRSA_Data_Dongsi_20130301-20170228.csv
# PRSA_Data_Guanyuan_20130301-20170228.csv
# PRSA_Data_Gucheng_20130301-20170228.csv
# PRSA_Data_Huairou_20130301-20170228.csv
# PRSA_Data_Nongzhanguan_20130301-20170228.csv
# PRSA_Data_Shunyi_20130301-20170228.csv
# PRSA_Data_Tiantan_20130301-20170228.csv
# PRSA_Data_Wanliu_20130301-20170228.csv
# PRSA_Data_Wanshouxigong_20130301-20170228.csv

# %%
def convert_to_date(x):
	return datetime.strptime(x, '%Y %m %d %H')

# %%
aq_df_sh = pd.read_csv('/tmp/aq/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv', parse_dates = [['year', 'month', 'day', 'hour']],date_parser=convert_to_date)

# %%
aq_df_wa = pd.read_csv('/tmp/aq/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv', parse_dates = [['year', 'month', 'day', 'hour']],date_parser=convert_to_date)

# %%
aq_df_gu = pd.read_csv('/tmp/aq/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv', parse_dates = [['year', 'month', 'day', 'hour']],date_parser=convert_to_date)

# %%
aq_df = pd.concat([aq_df_sh, aq_df_wa,aq_df_gu], ignore_index=True, sort=False)

# %%
aq_df
# Out:
#        year_month_day_hour     No  PM2.5  PM10  ...  RAIN   wd  WSPM  station
# 0      2013-03-01 00:00:00      1    3.0   6.0  ...   0.0   NW   9.3   Shunyi
# 1      2013-03-01 01:00:00      2   12.0  12.0  ...   0.0   NW   9.4   Shunyi
# 2      2013-03-01 02:00:00      3   14.0  14.0  ...   0.0   NW   8.6   Shunyi
# 3      2013-03-01 03:00:00      4   12.0  12.0  ...   0.0   NW   6.6   Shunyi
# 4      2013-03-01 04:00:00      5   12.0  12.0  ...   0.0   NW   4.5   Shunyi
# ...                    ...    ...    ...   ...  ...   ...  ...   ...      ...
# 105187 2017-02-28 19:00:00  35060   14.0  58.0  ...   0.0  NNW   3.1  Gucheng
# 105188 2017-02-28 20:00:00  35061   27.0  83.0  ...   0.0   NW   1.9  Gucheng
# 105189 2017-02-28 21:00:00  35062   22.0  37.0  ...   0.0    N   2.3  Gucheng
# 105190 2017-02-28 22:00:00  35063    9.0  23.0  ...   0.0   NE   1.6  Gucheng
# 105191 2017-02-28 23:00:00  35064   12.0  48.0  ...   0.0  NNE   0.7  Gucheng
#
# [105192 rows x 15 columns]

# %%
aq_df=aq_df.drop(['No'], axis=1)

# %%
aq_df
# Out:
#        year_month_day_hour  PM2.5  PM10  SO2  ...  RAIN   wd  WSPM  station
# 0      2013-03-01 00:00:00    3.0   6.0  3.0  ...   0.0   NW   9.3   Shunyi
# 1      2013-03-01 01:00:00   12.0  12.0  3.0  ...   0.0   NW   9.4   Shunyi
# 2      2013-03-01 02:00:00   14.0  14.0  NaN  ...   0.0   NW   8.6   Shunyi
# 3      2013-03-01 03:00:00   12.0  12.0  3.0  ...   0.0   NW   6.6   Shunyi
# 4      2013-03-01 04:00:00   12.0  12.0  3.0  ...   0.0   NW   4.5   Shunyi
# ...                    ...    ...   ...  ...  ...   ...  ...   ...      ...
# 105187 2017-02-28 19:00:00   14.0  58.0  4.0  ...   0.0  NNW   3.1  Gucheng
# 105188 2017-02-28 20:00:00   27.0  83.0  6.0  ...   0.0   NW   1.9  Gucheng
# 105189 2017-02-28 21:00:00   22.0  37.0  7.0  ...   0.0    N   2.3  Gucheng
# 105190 2017-02-28 22:00:00    9.0  23.0  3.0  ...   0.0   NE   1.6  Gucheng
# 105191 2017-02-28 23:00:00   12.0  48.0  5.0  ...   0.0  NNE   0.7  Gucheng
#
# [105192 rows x 14 columns]

# %%
aq_df = aq_df.set_index('year_month_day_hour').groupby('station').resample('D').mean()

# %%
aq_df
# Out:
#                                   PM2.5        PM10  ...  RAIN      WSPM
# station year_month_day_hour                          ...
# Gucheng 2013-03-01             8.625000   16.875000  ...   0.0  2.350000
#         2013-03-02            36.916667   51.375000  ...   0.0  1.087500
#         2013-03-03            80.333333  120.041667  ...   0.0  1.400000
#         2013-03-04            26.500000   51.291667  ...   0.0  1.541667
#         2013-03-05           136.708333  172.541667  ...   0.0  0.841667
# ...                                 ...         ...  ...   ...       ...
# Wanliu  2017-02-24            21.458333   39.666667  ...   0.0  1.262500
#         2017-02-25             8.250000   21.166667  ...   0.0  1.466667
#         2017-02-26            27.125000   44.583333  ...   0.0  1.562500
#         2017-02-27            64.000000   95.916667  ...   0.0  1.316667
#         2017-02-28             9.958333   25.583333  ...   0.0  1.800000
#
# [4383 rows x 11 columns]

# %%
aq_df=aq_df.reset_index()

# %%
aq_df.set_index('year_month_day_hour').query("station=='Shunyi'")[['O3','TEMP']].plot()

# %%
aq_df.set_index('year_month_day_hour').query("station=='Wanliu'")[['O3','TEMP']].plot()

# %%
aq_df.set_index('year_month_day_hour').query("station=='Gucheng'")[['O3','TEMP']].plot()

# %%
aq_df.set_index('year_month_day_hour').groupby('station')[['O3','TEMP']].plot()
# Out:
# station
# Gucheng    AxesSubplot(0.125,0.125;0.775x0.755)
# Shunyi     AxesSubplot(0.125,0.125;0.775x0.755)
# Wanliu     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
aq_df
# Out:
#       station year_month_day_hour       PM2.5  ...       DEWP  RAIN      WSPM
# 0     Gucheng          2013-03-01    8.625000  ... -19.691667   0.0  2.350000
# 1     Gucheng          2013-03-02   36.916667  ... -16.337500   0.0  1.087500
# 2     Gucheng          2013-03-03   80.333333  ... -11.991667   0.0  1.400000
# 3     Gucheng          2013-03-04   26.500000  ... -11.945833   0.0  1.541667
# 4     Gucheng          2013-03-05  136.708333  ...  -7.741667   0.0  0.841667
# ...       ...                 ...         ...  ...        ...   ...       ...
# 4378   Wanliu          2017-02-24   21.458333  ... -10.583333   0.0  1.262500
# 4379   Wanliu          2017-02-25    8.250000  ...  -9.900000   0.0  1.466667
# 4380   Wanliu          2017-02-26   27.125000  ...  -7.558333   0.0  1.562500
# 4381   Wanliu          2017-02-27   64.000000  ...  -6.333333   0.0  1.316667
# 4382   Wanliu          2017-02-28    9.958333  ... -12.266667   0.0  1.800000
#
# [4383 rows x 13 columns]

# %%
aq_df['station'].unique()
# Out:
# array(['Gucheng', 'Shunyi', 'Wanliu'], dtype=object)

# %%
from fbprophet import Prophet

# %%
aq_df_final=aq_df[['year_month_day_hour','O3','TEMP','station']].rename({'year_month_day_hour':'ds','O3':'y'}, axis='columns')

# %%
aq_df_final
# Out:
#              ds          y       TEMP  station
# 0    2013-03-01  77.130435   1.691667  Gucheng
# 1    2013-03-02  39.583333   0.820833  Gucheng
# 2    2013-03-03  33.708333   6.562500  Gucheng
# 3    2013-03-04  67.250000   9.795833  Gucheng
# 4    2013-03-05  84.375000   6.750000  Gucheng
# ...         ...        ...        ...      ...
# 4378 2017-02-24  38.583333   4.395833   Wanliu
# 4379 2017-02-25  56.375000   6.387500   Wanliu
# 4380 2017-02-26  30.250000   6.720833   Wanliu
# 4381 2017-02-27  17.136364   7.220833   Wanliu
# 4382 2017-02-28  54.791667  10.516667   Wanliu
#
# [4383 rows x 4 columns]

# %%
stations = aq_df_final.groupby('station')

# %%
stations.head()
# Out:
#              ds          y      TEMP  station
# 0    2013-03-01  77.130435  1.691667  Gucheng
# 1    2013-03-02  39.583333  0.820833  Gucheng
# 2    2013-03-03  33.708333  6.562500  Gucheng
# 3    2013-03-04  67.250000  9.795833  Gucheng
# 4    2013-03-05  84.375000  6.750000  Gucheng
# 1461 2013-03-01  62.478261  0.541667   Shunyi
# 1462 2013-03-02  40.416667  0.083333   Shunyi
# 1463 2013-03-03  24.541667  5.029167   Shunyi
# 1464 2013-03-04  55.125000  8.937500   Shunyi
# 1465 2013-03-05  74.541667  6.450000   Shunyi
# 2922 2013-03-01  46.347826  1.391667   Wanliu
# 2923 2013-03-02  17.666667  0.616667   Wanliu
# 2924 2013-03-03  12.083333  5.566667   Wanliu
# 2925 2013-03-04  31.750000  9.962500   Wanliu
# 2926 2013-03-05  48.541667  6.291667   Wanliu

# %%
for station in stations.groups:
    group = stations.get_group(station)
    train=group[(group['ds'] >= '2013-03-01') & (group['ds'] <= '2016-02-28')]
    test=group[(group['ds'] > '2016-02-28')]
    print(test.shape)

# %%
target = pd.DataFrame()

# %%
for station in stations.groups:
    group = stations.get_group(station)
    
    m = Prophet(interval_width=0.95)
    m.fit(group)
    future = m.make_future_dataframe(periods=366)
    forecast = m.predict(future)  
    m.plot(forecast)  
    forecast = forecast.rename(columns={'yhat': 'yhat_'+station})
    target = pd.merge(target, forecast.set_index('ds'), how='outer', left_index=True, right_index=True)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
target
# Out:
#               trend_x  yhat_lower_x  ...  multiplicative_terms_upper  yhat_Wanliu
# ds                                   ...
# 2013-03-01  49.084059     -8.316120  ...                         0.0    17.711409
# 2013-03-02  49.099025     -5.739818  ...                         0.0    20.052958
# 2013-03-03  49.113990     -6.881472  ...                         0.0    23.877200
# 2013-03-04  49.128956     -7.217237  ...                         0.0    24.392543
# 2013-03-05  49.143922     -8.169264  ...                         0.0    22.542686
# ...               ...           ...  ...                         ...          ...
# 2018-02-25  45.309038    -12.358691  ...                         0.0    38.722104
# 2018-02-26  45.286521    -12.239373  ...                         0.0    38.733790
# 2018-02-27  45.264005    -16.215511  ...                         0.0    36.456615
# 2018-02-28  45.241488    -14.443798  ...                         0.0    36.787718
# 2018-03-01  45.218971    -11.817075  ...                         0.0    39.171175
#
# [1827 rows x 54 columns]

# %%
target = target[['yhat_' + station for station in stations.groups.keys()]]

# %%
target
# Out:
#             yhat_Gucheng  yhat_Shunyi  yhat_Wanliu
# ds
# 2013-03-01     33.904191    33.895991    17.711409
# 2013-03-02     35.982524    34.231202    20.052958
# 2013-03-03     39.759538    39.392149    23.877200
# 2013-03-04     41.023505    38.861399    24.392543
# 2013-03-05     38.407914    38.510811    22.542686
# ...                  ...          ...          ...
# 2018-02-25     30.655595    42.999478    38.722104
# 2018-02-26     31.638301    41.894387    38.733790
# 2018-02-27     28.803092    41.047648    36.456615
# 2018-02-28     30.120386    41.604984    36.787718
# 2018-03-01     32.239386    42.166497    39.171175
#
# [1827 rows x 3 columns]

# %%
pd.concat([aq_df_final.set_index('ds').query("station=='Gucheng'")['y'],target['yhat_Gucheng']],axis=1).plot()

# %%
pd.concat([aq_df_final.set_index('ds').query("station=='Wanliu'")['y'],target['yhat_Wanliu']],axis=1).plot()
